# %%
import pandas as pd
import numpy as np

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Logistic Regression
from sklearn.linear_model import LogisticRegression
# XGBoost
from xgboost import XGBClassifier
# multilayer perceptron
from sklearn.neural_network import MLPClassifier

# %%
def load_data(data):
    """This function loads our data in a format that was described in the instructions"""
    data_df = pd.read_csv(data,sep =";")
    #The duration column had to be dropped as adviced in the data description
    data_df.drop('duration',axis=1,inplace=True)
    #for the pdays column,we set the 999 to 0 to indicate no previous contact
    print("loaded succsefuly")
    return data_df

# %%
data=load_data("bank-additional-full.csv")
# Out:
# loaded succsefuly

# %%
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

class Preprocesses:
    
    def __init__(self,data_df,target):
        self.data_df = data_df
        self.target = target
        
    def education_replacer(self):
        #having all the basic categories in one sub column of basic
        self.data_df.education = self.data_df.education.replace({"basic.4y":"basic",
                                                                 "basic.6y":"basic",
                                                                 "basic.9y":"basic"})
        
    def outlier_check(self):
        #creates dataframe to have our outlier data
        outliers_count_df = pd.DataFrame(columns=['Outlier_Count','skewness'])
        for column in self.data_df:
            if self.data_df.dtypes[column] == (np.int64 or np.float64):
                Q1 = self.data_df[column].quantile(0.25)
                Q3 = self.data_df[column].quantile(0.75)
                IQR = Q3-Q1
                lower_whisker = Q1-1.5*IQR
                upper_whisker = Q3+1.5*IQR
                outliers_count_df.loc[column] = [((self.data_df[column]<lower_whisker) | (self.data_df[column] > upper_whisker)).sum(),self.data_df[column].skew()]
        #selecting numerical columns with outliers
        outlier_col = outliers_count_df[outliers_count_df['Outlier_Count']>=1]
        self.outlier_col = outlier_col.T.columns
        return self.outlier_col
        
    def outlier_treatment(self):
        for i in self.outlier_col:
            if self.data_df.dtypes[i] == (np.int64 or np.float64):
                Q1 = self.data_df[i].quantile(0.25)
                Q3 = self.data_df[i].quantile(0.75)
                IQR = Q3 - Q1
                lower_range = Q1 -(1.5 * IQR)
                upper_range = Q3 + (1.5 * IQR)
                self.data_clean = self.data_df.drop(self.data_df[(self.data_df[i] > upper_range) | (self.data_df[i] < lower_range) ].index , inplace=True)
                return self.data_clean

    def standardizer(self):
        scale = StandardScaler()
        for i in self.data_clean.columns:
            if self.data_clean.dtypes[i] == (np.int64 or np.float64):
                self.data_clean[i] = scale.fit_transform(self.data_clean[[i]])
        return self.data_df_standard
    
    def encoder(self):
        data_encoded_df = pd.get_dummies(self.data_df,columns = categorical_col.drop(self.target,axis=1).columns)
        return data_encoded_df
    
    def balancing(self):
        X = self.data_df.drop(self.target,axis=1)
        y = self.data_df[self.target]
        os = SMOTE(random_state=0)
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
        columns = X_train.columns
        os_data_X,os_data_y=os.fit_sample(X_train, y_train)
        os_data_X = pd.DataFrame(data=os_data_X,columns=columns )
        os_data_y= pd.DataFrame(data=os_data_y,columns=['y'])

        # we can Check the numbers of our data
        '''
        print("length of oversampled data is ",len(os_data_X))
        print("Number of no subscription in oversampled data",len(os_data_y[os_data_y['y']==0]))
        print("Number of subscription",len(os_data_y[os_data_y['y']==1]))
        print("Proportion of no subscription data in oversampled data is ",len(os_data_y[os_data_y['y']==0])/len(os_data_X))
        print("Proportion of subscription data in oversampled data is ",len(os_data_y[os_data_y['y']==1])/len(os_data_X))
        '''
        return os_data_X,os_data_y,X_test,y_test
        
        def __iter__(self):
            '''Generator function.'''
            for i in self.data_df:
                yield i

# %%
pre = Preprocesses(data,'y')

# %%
pre.outlier_check()
# Out:
# Index(['age', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
pre.outlier_treatment()

# %%
data_clean =

# %%
pre2.standardizer()

# %%
class Model:
    def __init__(self,datafile,model_name=None):
        self.df = pd.read_csv(datafile)
        if model_name == 'lgr':
            self.lgr = LogisticRgression()
        if model_name == 'xgb':
            self.xgb = XGBClassifier()
        if model_name == 'mlp':
            self.mlp = MLPClassifier()
